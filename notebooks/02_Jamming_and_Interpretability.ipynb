# %% [markdown]
# ## Setup

# %%
import os, sys, platformREPO = os.getcwd()if not os.path.isdir(os.path.join(REPO, "src")):    REPO = "/content/dual-head-ultra-can"os.chdir(REPO); sys.path.insert(0, REPO)print("Repo:", REPO)print(platform.platform())

# %% [markdown]
# ## 1. Jamming experiment

# %%
# !python src/experiments/runner.py --experiments jamming --mode full

# %% [markdown]
# ## 2. Interpretability probe (zero training, uses the jamming models)

# %%
# !python src/experiments/runner.py --experiments jamming_interpretability --mode full

# %% [markdown]
# ## 3. Jamming-aware training of the QKV receiver (optional, long)

# %%
# !python scripts/run_jam_aware_qkv.py

# %% [markdown]
# ## 4. Figures

# %%
# !python scripts/make_fig_layer_retention.py

# %%
# !python scripts/make_fig_jamming_aware_control.py

# %% [markdown]
# Outputs: figures/jamming_layer_retention.pdf and figures/jamming_aware_control.pdf
