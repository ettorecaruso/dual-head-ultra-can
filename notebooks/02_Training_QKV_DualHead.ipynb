# %% [markdown]
# # Training Ultra-CAN (QKV) on the aerial linkTrains the multi-head QKV variant (43,172 parameters) on the single-echo scenario.

# %%
import sys
from pathlib import Path
import numpy as np
sys.path.insert(0, str(Path.cwd()))

# %%
from src import models
model = models.build_model('qkv')
print('params', model.count_params())

# %% [markdown]
# ## Short smoke training

# %%
from src import training
training.train_model('qkv', n_train=2000, n_val=400, epochs=1)

# %% [markdown]
# The QKV variant is the most robust receiver in the dense-swarm scenarios.
