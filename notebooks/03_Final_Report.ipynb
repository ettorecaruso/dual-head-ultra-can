# %% [markdown]
# ## Setup

# %%
import os, sys, platform
REPO = os.getcwd()
if not os.path.isdir(os.path.join(REPO, "src")):
    REPO = "/content/dual-head-ultra-can"
os.chdir(REPO); sys.path.insert(0, REPO)
print("Repo:", REPO)
print(platform.platform())

# %% [markdown]
# ## 1. Weight table and aggregated final report

# %%
# !python src/experiments/runner.py --experiments final_report --mode full

# %% [markdown]
# ## 2. Single-burst latency benchmark

# %%
# !python scripts/latency_bench.py

# %% [markdown]
# The report is written to results/full/final_report/final_report.md; the SWaP-C
# table to results/full/final_report/weight_table.tex.
