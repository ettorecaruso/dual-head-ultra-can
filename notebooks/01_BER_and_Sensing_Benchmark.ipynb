# %% [markdown]
# ## Setup

# %%
import os, sys, platformREPO = os.getcwd()if not os.path.isdir(os.path.join(REPO, "src")):    REPO = "/content/dual-head-ultra-can"os.chdir(REPO); sys.path.insert(0, REPO)print("Repo:", REPO)print(platform.platform())

# %% [markdown]
# ## 1. Communication benchmark (ber_vs_snr)

# %%
# !python src/experiments/runner.py --experiments ber_vs_snr --mode full

# %% [markdown]
# ## 2. Classical receivers (equations-only, no figures)

# %%
# !python src/experiments/runner.py --experiments classical_receivers --mode full

# %% [markdown]
# ## 3. Figures and operating-region tables

# %%
# !python scripts/make_fig_ber_full_linear.py

# %%
# !python scripts/make_fig_ber_region_zoom.py

# %%
# !python scripts/make_fig_sensing_delay.py

# %%
# !python scripts/make_table_operating_region.py

# %% [markdown]
# Outputs: figures/ber_full_linear.pdf, figures/ber_region_zoom.pdf,figures/sensing_delay_single.pdf and results/full/ber_vs_snr/operating_region_table.csv
