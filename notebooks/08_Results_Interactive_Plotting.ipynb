# %% [markdown]
# # Interactive results explorerAggregates the committed results into a single explorer to browse BER, sensing and jamming tables without rerunning experiments.

# %%
import sys
from pathlib import Path
import numpy as np
sys.path.insert(0, str(Path.cwd()))

# %% [markdown]
# ## Commit summary

# %%
import pandas as pd
ber = pd.read_csv('results/curves/ber_curves.csv')
print(ber.groupby(['scenario', 'model']).ber.min().unstack())

# %% [markdown]
# All paper figures are stored in `results/figures/` and can be reproduced with `python scripts/make_figures.py`.
