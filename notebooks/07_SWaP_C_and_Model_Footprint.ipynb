# %% [markdown]
# # SWaP-C comparison and model footprintCounts the trainable parameters and the float32 memory footprint of the evaluated receivers, reproducing Table III of the paper.

# %%
import sys
from pathlib import Path
import numpy as np
sys.path.insert(0, str(Path.cwd()))

# %%
from src import swapc
print(swapc.load_weight_table().to_string(index=False))

# %% [markdown]
# Reported numbers: Conv1D 26,597 (103.9 kB), QKV 43,172 (168.6 kB), LSTM-OFDM-DCSK 45,988 (179.6 kB), MC-DLCSK 44,756 (174.8 kB).
